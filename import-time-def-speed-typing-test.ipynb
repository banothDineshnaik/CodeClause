# %%
import time

def speed_typing_test():
    prompt = "The quick brown fox jumps over the lazy dog."
    print("Type the following sentence as fast as you can:\n")
    print(prompt)
    input("Press Enter when you're ready...")
    
    start_time = time.time()
    user_input = input("Start typing: ")
    end_time = time.time()
    
    elapsed_time = end_time - start_time
    words = prompt.split()
    typed_words = user_input.split()
    
    correct_words = 0
    for word1, word2 in zip(words, typed_words):
        if word1 == word2:
            correct_words += 1
    
    accuracy = (correct_words / len(words)) * 100
    words_per_minute = (len(typed_words) / elapsed_time) * 60
    
    print("\nTime taken:", round(elapsed_time, 2), "seconds")
    print("Accuracy:", round(accuracy, 2), "%")
    print("Words per minute:", round(words_per_minute, 2))

if __name__ == "__main__":
    speed_typing_test()
# Out:
# Type the following sentence as fast as you can:
#
# The quick brown fox jumps over the lazy dog.
# Press Enter when you're ready... the quick brown fox jump over the lazy dog
# Start typing:  the quick brown fox jumps over the lazy dog
# Time taken: 21.39 seconds
# Accuracy: 77.78 %
# Words per minute: 25.24
